# %%
import pandas as pd
import seaborn as sns

col_df = pd.read_csv("College_Data").iloc[:, 1:]
col_df.head(10)
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
# 5     Yes   587     479     158         38         62          678
# 6     Yes   353     340     103         17         45          416
# 7     Yes  1899    1720     489         37         68         1594
# 8     Yes  1038     839     227         30         63          973
# 9     Yes   582     498     172         21         44          799
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# ...

# %%
col_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    object
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    float64
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
#  17  Grad.Rate    777 non-null    int64
# dtypes: float64(1), int64(16), object(1)
# ...

# %%
col_df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
import seaborn as sns

sns.countplot(x=col_df["Private"], label="count")
# Out:
# <AxesSubplot:xlabel='Private', ylabel='count'>

# %%
sns.scatterplot(data=col_df, x="Room.Board", y="Grad.Rate", hue="Private")
# Out:
# <AxesSubplot:xlabel='Room.Board', ylabel='Grad.Rate'>

# %%
sns.scatterplot(data=col_df, y="F.Undergrad", x="Outstate", hue="Private")
# Out:
# <AxesSubplot:xlabel='Outstate', ylabel='F.Undergrad'>

# %%
col_df.hist(column="Outstate", by="Private")
# Out:
# array([<AxesSubplot:title={'center':'No'}>,
#        <AxesSubplot:title={'center':'Yes'}>], dtype=object)

# %%
col_df.hist(column="Grad.Rate", by="Private")
# Out:
# array([<AxesSubplot:title={'center':'No'}>,
#        <AxesSubplot:title={'center':'Yes'}>], dtype=object)

# %%
sns.pairplot(col_df,hue="Private", vars=["Grad.Rate","Books","PhD"])

# %%
from sklearn.preprocessing import LabelEncoder

X = col_df.drop(["Private"],axis=1)
y = col_df["Private"]

y = LabelEncoder().fit_transform(y)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report

km = KMeans(n_clusters = 2)
km.fit(X)

print(classification_report(y,km.labels_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.21      0.65      0.31       212
#            1       0.31      0.06      0.10       565
#
#     accuracy                           0.22       777
#    macro avg       0.26      0.36      0.21       777
# weighted avg       0.29      0.22      0.16       777

# %%
col_df["cluster"] = km.labels_

sns.pairplot(col_df,hue="cluster", vars=["Grad.Rate","Books","PhD"])
